# %% [markdown]
# - 센트로이드: KMeans 알고리즘에서 각 샘플의 거리를 평균을 내서 군집화를 하여 최종 군집화 한 각 군집들의 중심값(평균값)
#
# - 메도이드 : 센트로이드에서 가장 가까운 실제 샘플을 센트로이드 대신 중심값으로 사용하는 방법
#
# - sklearn에는 메도이드 방식의 KMeans 알고리즘 방식은 구현되어 있지 않음

# %% [markdown]
# ### 차원 축소 (Dimensionality Reduction)

# %% [markdown]
# ### 주성분 분석
